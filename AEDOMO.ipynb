# %% [markdown]
# <a href="https://colab.research.google.com/github/MeireBe/Meire/blob/main/AEDOMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Análise Exploratória - Estudo de Caso OMO**
#
# ---

# %% [markdown]
# ![OMO.jpg](data:image/jpeg;base64,...)

# %%
# @title 1. Importa as bibliotecas necessárias para a Análise Exploratória de Dados (AED)
import io
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
# @title 2. Importa o arquivo Atividade 2 Omo.csv para o dataframe df_omo
from google.colab import files
uploaded = files.upload()
df_omo = pd.read_excel('Atividade 2 - Omo.xlsx')
# Out:
#      <input type="file" id="files-b9e4c17b-3df3-4ba5-bff2-285f09cbb5a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9e4c17b-3df3-4ba5-bff2-285f09cbb5a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# @title 3. Visualiza o arquivo Atividade 2 Omo.csv importado
df_omo
# Out:
#      1060
# 0     991
# 1    1032
# 2    1017
# 3    1066
# 4    1031
# ..    ...
# 995  1034
# 996  1059
# 997  1005
# 998  1014
# 999   980
#
# [1000 rows x 1 columns]

# %%
# @title 4. Renomeia a coluna de dados
nome_coluna = ['PESO']
df_omo = pd.DataFrame(df_omo.values,columns=nome_coluna)
df_omo
# Out:
#      PESO
# 0     991
# 1    1032
# 2    1017
# 3    1066
# 4    1031
# ..    ...
# 995  1034
# 996  1059
# 997  1005
# 998  1014
# 999   980
#
# [1000 rows x 1 columns]

# %%
# @title 5. Gera estatísticas de tendência central para o campo PESO
# Calcula as medidas de tendência central

contagem = df_omo['PESO'].count()
media = df_omo['PESO'].mean()
moda = statistics.mode(df_omo['PESO'])
minimo = df_omo['PESO'].min()
Q1 = df_omo['PESO'].quantile(0.25)
mediana = df_omo['PESO'].median()
Q3 = df_omo['PESO'].quantile(0.75)
maximo = df_omo['PESO'].max()
AIQ = Q3 - Q1
outlier_sup = Q3 + (1.5 * AIQ)
outlier_inf = Q1 - (1.5 * AIQ)

# Exibe os resultados

peso_esperado_max = 1000 * 1.03
peso_esperado_min = 1000 * 0.97

print(f"Peso Esperado Máximo: {peso_esperado_max:.0f}")
print(f"Peso Esperado Mínimo: {peso_esperado_min:.0f}")
print(' ')
print(f"Contagem: {contagem:.2f}")
print(f"Média: {media:.2f}")
print(f"Moda: {moda:.2f}")
print(f"Mínimo: {minimo:.2f}")
print(f"Q1: {Q1:.2f}")
print(f"Mediana = Q2: {mediana:.2f}")
print(f"Q3: {Q3:.2f}")
print(f"Máximo: {maximo:.2f}")
print(f"Amplitude Interquartil (AIQ): {AIQ:.2f}")
print(f"Outliers Inferiores: {outlier_inf:.2f}")
print(f"Outliers Superiores: {outlier_sup:.2f}")
print(' ')

# Análises específicas

if media == mediana:
  print('A distribuição de dados é simétrica.')
elif media < mediana:
  print('A distribuição de dados é assimétrica com valores menores à esquerda.')
else:
  print('A distribuição de dados é assimétrica com valores maioress à direita.')
# Out:
# Peso Esperado Máximo: 1030
# Peso Esperado Mínimo: 970
#
# Contagem: 1000.00
# Média: 999.59
# Moda: 944.00
# Mínimo: 930.00
# Q1: 964.00
# Mediana = Q2: 1001.00
# Q3: 1036.25
# Máximo: 1070.00
# Amplitude Interquartil (AIQ): 72.25
# Outliers Inferiores: 855.62
# Outliers Superiores: 1144.62
#
# A distribuição de dados é assimétrica com valores menores à esquerda.

# %%
# @title 6. Desenha o boxplot utilizando a biblioteca Seaborn

sns.set_palette("pastel")
sns.boxplot(x=df_omo['PESO'], color='orange', width=0.2, showmeans = True)
plt.xticks(np.arange(900, 1100, 20))
plt.title('Peso das Embalagens de OMO')
plt.xlabel('Peso (gramas)')
plt.show()

# %%
# @title 7. Gera estatísticas de dispersão para o campo PESO
# Calcular a variância

variancia = df_omo['PESO'].var()

# Calcular o desvio padrão
desvio_padrao = df_omo['PESO'].std()

# Calcular CV%
cvp = (desvio_padrao/ media)*100

print(f'Variância: {variancia:.2f}')
print(f'Desvio Padrão: {desvio_padrao:.2f}')
print(f'CV%: {cvp:.2f} %')
# Out:
# Variância: 1691.88
# Desvio Padrão: 41.13
# CV%: 4.11 %

# %% [markdown]
# **8. CONCLUSÃO **
# As 1001 amostras de peso, medida em gramas, de caixas de sabão em pó OMO, cujo peso nominal é 1kg mostram que: . 25% das caixas têm peso menor que 964 gramas (Q1).
#
# Só por essa medida sabemos que as caixas estão NÃO CONFORMES, pois a totalidade da amostra deveria estar entre 970g e 1030g. . 50% das caixas têm peso menor que 1001 gramas (mediana = Q2) . 75% das caixas têm peso menor que 1037 gramas (Q3).
#
# Essa informação mostra que 25% das caixas entre Q2 e Q3 tem uma variação de peso entre 1001g (Q2) e 1037g (Q3). . O coeficiente de variação percentual, baseado na divisão do desvio padrão pela média indica uma variação de 4,12%, acima do máximo permitido de 3%.
